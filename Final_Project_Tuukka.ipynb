# %%
from nba_api.stats.static import players, teams
from nba_api.stats.endpoints import commonplayerinfo,leaguegamefinder, playergamelog, playercareerstats, commonteamroster
from nba_api.stats.library.parameters import SeasonAll
import requests as re
import pandas as pd
import datetime
import time

# Get a date of the birthday for current season
def get_date(x, season_starting_year):
    now = datetime.datetime.now()
    
    current_month = now.month
    current_day = now.day
    if x.month == 2 and x.day == 29:
        if (season_starting_year + 1) % 4 == 0 and (season_starting_year + 1) % 100 != 0 or (season_starting_year + 1) % 400 == 0:
            x = datetime.datetime(season_starting_year + 1, x.month, x.day)
        else:
            x = datetime.datetime(season_starting_year + 1, x.month, x.day - 1)
    else:
        if x.month >= 10:
            x = datetime.datetime(season_starting_year, x.month, x.day)
        elif x.month < 7:
            x = datetime.datetime(season_starting_year + 1, x.month, x.day)
        else:
            x = None
        
    return x

def get_team_ids():
    # Retrieve all NBA teams
    nba_teams = teams.get_teams()
    
    team_ids = {}
    
    # Extract team IDs
    for team in nba_teams:
        
        team_ids[team["full_name"]] = team['id']
    
    return team_ids

def get_list_players(year):

    season = str(year) + '-' + str(year + 1)[2:4]

    season

    player_list = pd.DataFrame()

    for team_id in get_team_ids().values():
        print(f'Fetching team id: {team_id}')
        roster = commonteamroster.CommonTeamRoster(team_id, season)
        roster_df = roster.get_data_frames()[0]
        player_list = pd.concat([player_list, roster_df], ignore_index = True)
        time.sleep(1)

    return player_list


# Get player info on the active players
def get_player_info(year):
    
    df = get_list_players(year)
    
    df['BIRTH_DATE'] = pd.to_datetime(df['BIRTH_DATE'], format = '%b %d, %Y')
        
    df['Date'] = df['BIRTH_DATE'].apply(lambda x: get_date(x, year))
    
    df = df[df['Date'] < (datetime.datetime.now() - datetime.timedelta(days=7))] #Find a way to resolve an issue if there is no game after the date

    return df

# Get the game id of the first game after a birthday
def get_game_id(team_id, date):
    
    gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_id)
    df = gamefinder.get_data_frames()[0]
    
    df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
    df = df[df['GAME_DATE'] > date]
    
    df = df.sort_values('GAME_DATE', ascending = True)
    
    if df.empty:
        print("DataFrame is empty")
    else:
        return df.iloc[0, [0,4]]

# Return a row with a difference of the season and post birthday game stats, birthday - season
def get_stat_diff(player_name, player_id, game_id, season_id):
    
    game_log = playergamelog.PlayerGameLog(player_id=player_id, season=SeasonAll.all, season_type_all_star = 'Regular Season')
    game_log_df = game_log.get_data_frames()[0]

    season_avg = game_log_df[game_log_df['SEASON_ID'] == season_id]

    season_avg = pd.DataFrame(season_avg.select_dtypes(include=['int64', 'float64']).mean()).T

    specific_game_log_df = game_log_df[game_log_df['Game_ID'] == game_id]

    comb = pd.concat([season_avg,specific_game_log_df], join = 'inner', ignore_index= True)

    diff = comb.diff()

    diff.dropna(inplace=True)
    
    diff['Player_ID'] = player_id
    diff.insert(loc = 1, column = 'Player_Name', value = player_name)
    
    return diff

def create_stat_diff_df(year):
    
    all_player_info = get_player_info(year)

    player_stat_diff = pd.DataFrame()
    initial_count = 0
    total_count = len(all_player_info)

    for index, player in all_player_info.iterrows():
        initial_count += 1
        player_id = player['PLAYER_ID']
        print(f'{initial_count}/{total_count} Fetching player with id: {player_id}')
        team_id = player['TeamID']
        orig_date = pd.to_datetime(player['Date'])
        player_name = player['PLAYER']
        season_id, game_id = get_game_id(team_id, orig_date)
        stat_diff = get_stat_diff(player_name,player_id, game_id, season_id)
        player_stat_diff = pd.concat([player_stat_diff, stat_diff], ignore_index=True)
        time.sleep(1)
        
    return player_stat_diff

# Combine dataframes
def combine_df(year_start, year_end):
    player_stat_diff_to_season_avg = pd.DataFrame()
    for year in range(year_start,year_end+1,1):
        print(f'Creating Year: {year}')
        season = str(year) + '-' + str(year + 1)[2:4]
        data = pd.read_csv(r"C:\\Users\\tuke-\\OneDrive - Cal Poly\\2_Winter_2024\\GSB521\\" + str(year) + '_data.csv')
        data.insert(loc = 0, column = 'Season', value = season)
        player_stat_diff_to_season_avg = pd.concat([player_stat_diff_to_season_avg, data], ignore_index = True)
    return player_stat_diff_to_season_avg

# %%
# Write Dataframes
for year in range(2021,2023,1):
    print(f'Creating Year: {year}')
    data = create_stat_diff_df(year)
    data.to_csv(r"C:\\Users\\tuke-\\OneDrive - Cal Poly\\2_Winter_2024\\GSB521\\" + str(year) + '_data.csv', index=False)
# Out:
# Creating Year: 2021
# Fetching team id: 1610612737
# Fetching team id: 1610612738
# Fetching team id: 1610612739
# Fetching team id: 1610612740
# Fetching team id: 1610612741
# Fetching team id: 1610612742
# Fetching team id: 1610612743
# Fetching team id: 1610612744
# Fetching team id: 1610612745
# Fetching team id: 1610612746
# Fetching team id: 1610612747
# Fetching team id: 1610612748
# Fetching team id: 1610612749
# Fetching team id: 1610612750
# Fetching team id: 1610612751
# Fetching team id: 1610612752
# Fetching team id: 1610612753
# Fetching team id: 1610612754
# Fetching team id: 1610612755
# Fetching team id: 1610612756
# Fetching team id: 1610612757
# Fetching team id: 1610612758
# Fetching team id: 1610612759
# Fetching team id: 1610612760
# Fetching team id: 1610612761
# Fetching team id: 1610612762
# Fetching team id: 1610612763
# Fetching team id: 1610612764
# Fetching team id: 1610612765
# Fetching team id: 1610612766
# 1/353 Fetching player with id: 1626153
# 2/353 Fetching player with id: 1630552
# 3/353 Fetching player with id: 1630536
# 4/353 Fetching player with id: 101150
# 5/353 Fetching player with id: 1627789
# 6/353 Fetching player with id: 203476
# 7/353 Fetching player with id: 1629631
# 8/353 Fetching player with id: 203991
# 9/353 Fetching player with id: 1630168
# 10/353 Fetching player with id: 1630602
# 11/353 Fetching player with id: 1630346
# 12/353 Fetching player with id: 1628369
# 13/353 Fetching player with id: 1627759
# 14/353 Fetching player with id: 1630202
# 15/353 Fetching player with id: 1629684
# 16/353 Fetching player with id: 203917
# 17/353 Fetching player with id: 1629752
# 18/353 Fetching player with id: 1630174
# 19/353 Fetching player with id: 1628464
# 20/353 Fetching player with id: 1630573
# 21/353 Fetching player with id: 203935
# 22/353 Fetching player with id: 201143
# 23/353 Fetching player with id: 1629057
# 24/353 Fetching player with id: 1630271
# 25/353 Fetching player with id: 1629164
# 26/353 Fetching player with id: 200765
# 27/353 Fetching player with id: 1629012
# 28/353 Fetching player with id: 1630596
# 29/353 Fetching player with id: 1630612
# 30/353 Fetching player with id: 1629650
# 31/353 Fetching player with id: 1629636
# 32/353 Fetching player with id: 1626224
# 33/353 Fetching player with id: 202334
# 34/353 Fetching player with id: 1628374
# 35/353 Fetching player with id: 1628386
# 36/353 Fetching player with id: 1629731
# 37/353 Fetching player with id: 1630171
# 38/353 Fetching player with id: 1628984
# 39/353 Fetching player with id: 1630529
# 40/353 Fetching player with id: 1630230
# 41/353 Fetching player with id: 1626195
# 42/353 Fetching player with id: 1629637
# 43/353 Fetching player with id: 1629109
# 44/353 Fetching player with id: 1630184
# 45/353 Fetching player with id: 1630631
# 46/353 Fetching player with id: 202685
# 47/353 Fetching player with id: 203503
# 48/353 Fetching player with id: 1626204
# 49/353 Fetching player with id: 1630530
# 50/353 Fetching player with id: 202066
# 51/353 Fetching player with id: 1629632
# 52/353 Fetching player with id: 1628366
# 53/353 Fetching player with id: 202684
# 54/353 Fetching player with id: 1627884
# 55/353 Fetching player with id: 1627936
# 56/353 Fetching player with id: 203897
# 57/353 Fetching player with id: 202696
# 58/353 Fetching player with id: 1630245
# 59/353 Fetching player with id: 1628396
# 60/353 Fetching player with id: 1630792
# 61/353 Fetching player with id: 1630250
# 62/353 Fetching player with id: 1628425
# 63/353 Fetching player with id: 1629033
# 64/353 Fetching player with id: 203504
# 65/353 Fetching player with id: 1630589
# 66/353 Fetching player with id: 1630182
# 67/353 Fetching player with id: 1627827
# 68/353 Fetching player with id: 203501
# 69/353 Fetching player with id: 203493
# 70/353 Fetching player with id: 203915
# 71/353 Fetching player with id: 1628467
# 72/353 Fetching player with id: 202722
# 73/353 Fetching player with id: 1629029
# 74/353 Fetching player with id: 1630210
# 75/353 Fetching player with id: 203210
# 76/353 Fetching player with id: 1629008
# 77/353 Fetching player with id: 203115
# 78/353 Fetching player with id: 1630267
# 79/353 Fetching player with id: 1628432
# 80/353 Fetching player with id: 1628420
# 81/353 Fetching player with id: 203999
# 82/353 Fetching player with id: 1630192
# 83/353 Fetching player with id: 1627750
# 84/353 Fetching player with id: 1628427
# 85/353 Fetching player with id: 1627780
# 86/353 Fetching player with id: 1630228
# 87/353 Fetching player with id: 1627814
# 88/353 Fetching player with id: 1629185
# 89/353 Fetching player with id: 1629673
# 90/353 Fetching player with id: 1630541
# 91/353 Fetching player with id: 1626172
# 92/353 Fetching player with id: 202357
# 93/353 Fetching player with id: 2738
# 94/353 Fetching player with id: 202691
# 95/353 Fetching player with id: 203952
# 96/353 Fetching player with id: 203110
# 97/353 Fetching player with id: 201939
# 98/353 Fetching player with id: 203490
# 99/353 Fetching player with id: 1630164
# 100/353 Fetching player with id: 1629308
# 101/353 Fetching player with id: 1630224
# 102/353 Fetching player with id: 1628021
# 103/353 Fetching player with id: 1629645
# 104/353 Fetching player with id: 1630231
# 105/353 Fetching player with id: 1630256
# 106/353 Fetching player with id: 1630528
# 107/353 Fetching player with id: 201569
# 108/353 Fetching player with id: 1630227
# 109/353 Fetching player with id: 1630586
# 110/353 Fetching player with id: 1630243
# 111/353 Fetching player with id: 1629726
# 112/353 Fetching player with id: 1630237
# 113/353 Fetching player with id: 202704
# 114/353 Fetching player with id: 202695
# 115/353 Fetching player with id: 1630527
# 116/353 Fetching player with id: 1628379
# 117/353 Fetching player with id: 1629599
# 118/353 Fetching player with id: 202331
# 119/353 Fetching player with id: 1629611
# 120/353 Fetching player with id: 1629875
# 121/353 Fetching player with id: 203918
# 122/353 Fetching player with id: 203496
# 123/353 Fetching player with id: 1626181
# 124/353 Fetching player with id: 201587
# 125/353 Fetching player with id: 1627826
# 126/353 Fetching player with id: 1628392
# 127/353 Fetching player with id: 201566
# 128/353 Fetching player with id: 201961
# 129/353 Fetching player with id: 203076
# 130/353 Fetching player with id: 201571
# 131/353 Fetching player with id: 1629659
# 132/353 Fetching player with id: 2544
# 133/353 Fetching player with id: 2546
# 134/353 Fetching player with id: 1628370
# 135/353 Fetching player with id: 1626169
# 136/353 Fetching player with id: 1630559
# 137/353 Fetching player with id: 202340
# 138/353 Fetching player with id: 1629117
# 139/353 Fetching player with id: 1630644
# 140/353 Fetching player with id: 2730
# 141/353 Fetching player with id: 1629216
# 142/353 Fetching player with id: 203506
# 143/353 Fetching player with id: 200768
# 144/353 Fetching player with id: 1628539
# 145/353 Fetching player with id: 1629639
# 146/353 Fetching player with id: 1630606
# 147/353 Fetching player with id: 200782
# 148/353 Fetching player with id: 1629312
# 149/353 Fetching player with id: 1629622
# 150/353 Fetching player with id: 2617
# 151/353 Fetching player with id: 1629130
# 152/353 Fetching player with id: 1630209
# 153/353 Fetching player with id: 201588
# 154/353 Fetching player with id: 1628960
# 155/353 Fetching player with id: 1626171
# 156/353 Fetching player with id: 201572
# 157/353 Fetching player with id: 201950
# 158/353 Fetching player with id: 202083
# 159/353 Fetching player with id: 1626192
# 160/353 Fetching player with id: 1629623
# 161/353 Fetching player with id: 203507
# 162/353 Fetching player with id: 1630572
# 163/353 Fetching player with id: 1626156
# 164/353 Fetching player with id: 1627736
# 165/353 Fetching player with id: 1629162
# 166/353 Fetching player with id: 1629020
# 167/353 Fetching player with id: 1627774
# 168/353 Fetching player with id: 1627752
# 169/353 Fetching player with id: 202328
# 170/353 Fetching player with id: 1630593
# 171/353 Fetching player with id: 1626157
# 172/353 Fetching player with id: 201933
# 173/353 Fetching player with id: 1630561
# 174/353 Fetching player with id: 201609
# 175/353 Fetching player with id: 202681
# 176/353 Fetching player with id: 1630549
# 177/353 Fetching player with id: 1630560
# 178/353 Fetching player with id: 1629651
# 179/353 Fetching player with id: 1630167
# 180/353 Fetching player with id: 203457
# 181/353 Fetching player with id: 201565
# 182/353 Fetching player with id: 1630193
# 183/353 Fetching player with id: 1629656
# 344/353 Fetching player with id: 202738
# 345/353 Fetching player with id: 1629667
# 346/353 Fetching player with id: 1626149
# 347/353 Fetching player with id: 1626162
# 348/353 Fetching player with id: 1630208
# 349/353 Fetching player with id: 1630575
# 350/353 Fetching player with id: 202330
# 351/353 Fetching player with id: 1630539
# 352/353 Fetching player with id: 203486
# 353/353 Fetching player with id: 1629083
# Creating Year: 2022
# Fetching team id: 1610612737
# Fetching team id: 1610612738
# Fetching team id: 1610612739
# Fetching team id: 1610612740
# Fetching team id: 1610612741
# Fetching team id: 1610612742
# Fetching team id: 1610612743
# Fetching team id: 1610612744
# Fetching team id: 1610612745
# Fetching team id: 1610612746
# Fetching team id: 1610612747
# Fetching team id: 1610612748
# Fetching team id: 1610612749
# Fetching team id: 1610612750
# Fetching team id: 1610612751
# Fetching team id: 1610612752
# Fetching team id: 1610612753
# Fetching team id: 1610612754
# Fetching team id: 1610612755
# Fetching team id: 1610612756
# Fetching team id: 1610612757
# Fetching team id: 1610612758
# Fetching team id: 1610612759
# Fetching team id: 1610612760
# Fetching team id: 1610612761
# Fetching team id: 1610612762
# Fetching team id: 1610612763
# Fetching team id: 1610612764
# Fetching team id: 1610612765
# Fetching team id: 1610612766
# 1/355 Fetching player with id: 1630552
# 2/355 Fetching player with id: 1630235
# 3/355 Fetching player with id: 1629631
# 4/355 Fetching player with id: 203991
# 5/355 Fetching player with id: 1630168
# 6/355 Fetching player with id: 1631213
# 7/355 Fetching player with id: 1629726
# 8/355 Fetching player with id: 1630249
# 9/355 Fetching player with id: 1630180
# 10/355 Fetching player with id: 1628369
# 11/355 Fetching player with id: 1627759
# 12/355 Fetching player with id: 1630202
# 13/355 Fetching player with id: 1629684
# 14/355 Fetching player with id: 1627763
# 15/355 Fetching player with id: 1631120
# 16/355 Fetching player with id: 1630573
# 17/355 Fetching player with id: 203935
# 18/355 Fetching player with id: 201143
# 19/355 Fetching player with id: 1629057
# 20/355 Fetching player with id: 201933
# 21/355 Fetching player with id: 1630551
# 22/355 Fetching player with id: 1630596
# 23/355 Fetching player with id: 1629636
# 24/355 Fetching player with id: 201937
# 25/355 Fetching player with id: 201980
# 26/355 Fetching player with id: 1626224
# 27/355 Fetching player with id: 203526
# 28/355 Fetching player with id: 1630241
# 29/355 Fetching player with id: 1629603
# 30/355 Fetching player with id: 1628386
# 31/355 Fetching player with id: 1629731
# 32/355 Fetching player with id: 201577
# 33/355 Fetching player with id: 1630171
# 34/355 Fetching player with id: 1631220
# 35/355 Fetching player with id: 1630529
# 36/355 Fetching player with id: 1630230
# 37/355 Fetching player with id: 1626195
# 38/355 Fetching player with id: 1629637
# 39/355 Fetching player with id: 1630700
# 40/355 Fetching player with id: 1630184
# 41/355 Fetching player with id: 1630631
# 42/355 Fetching player with id: 202685
# 43/355 Fetching player with id: 1626204
# 44/355 Fetching player with id: 1630530
# 45/355 Fetching player with id: 1630604
# 46/355 Fetching player with id: 202066
# 287/355 Fetching player with id: 1629026
# 288/355 Fetching player with id: 1630526
# 289/355 Fetching player with id: 203115
# 290/355 Fetching player with id: 1631199
# 291/355 Fetching player with id: 1627751
# 292/355 Fetching player with id: 1630288
# 293/355 Fetching player with id: 201152
# 294/355 Fetching player with id: 1630201
# 295/355 Fetching player with id: 1627832
# 296/355 Fetching player with id: 1628449
# 297/355 Fetching player with id: 203490
# 298/355 Fetching player with id: 1629018
# 299/355 Fetching player with id: 1631132
# 300/355 Fetching player with id: 1627783
# 301/355 Fetching player with id: 1630625
# 302/355 Fetching player with id: 1629659
# 303/355 Fetching player with id: 203903
# 304/355 Fetching player with id: 1629012
# 305/355 Fetching player with id: 1627739
# 306/355 Fetching player with id: 1630176
# 307/355 Fetching player with id: 1627745
# 308/355 Fetching player with id: 1631323
# 309/355 Fetching player with id: 1629677
# 310/355 Fetching player with id: 1628374
# 311/355 Fetching player with id: 1630695
# 312/355 Fetching player with id: 1630534
# 313/355 Fetching player with id: 1630548
# 314/355 Fetching player with id: 203482
# 315/355 Fetching player with id: 1629308
# 316/355 Fetching player with id: 1630214
# 317/355 Fetching player with id: 1631222
# 318/355 Fetching player with id: 1630583
# 319/355 Fetching player with id: 1628379
# 320/355 Fetching player with id: 1626145
# 321/355 Fetching player with id: 1630217
# 322/355 Fetching player with id: 1628415
# 323/355 Fetching player with id: 1631223
# 324/355 Fetching player with id: 1629723
# 325/355 Fetching player with id: 1631098
# 326/355 Fetching player with id: 203078
# 327/355 Fetching player with id: 1630692
# 328/355 Fetching player with id: 1630166
# 329/355 Fetching player with id: 1630225
# 330/355 Fetching player with id: 1630264
# 331/355 Fetching player with id: 1629655
# 332/355 Fetching player with id: 1628420
# 333/355 Fetching player with id: 1630557
# 334/355 Fetching player with id: 1626153
# 335/355 Fetching player with id: 201959
# 336/355 Fetching player with id: 1631105
# 337/355 Fetching player with id: 1630164
# 338/355 Fetching player with id: 1630181
# 339/355 Fetching player with id: 1631093
# 340/355 Fetching player with id: 1631205
# 341/355 Fetching player with id: 1630191
# 342/355 Fetching player with id: 1628963
# 343/355 Fetching player with id: 202711
# 344/355 Fetching player with id: 1630647
# 345/355 Fetching player with id: 1626179
# 346/355 Fetching player with id: 1630208
# 347/355 Fetching player with id: 1631109
# 348/355 Fetching player with id: 1631121
# 349/355 Fetching player with id: 1628372
# 350/355 Fetching player with id: 1630177
# 351/355 Fetching player with id: 1626162
# 352/355 Fetching player with id: 1629004
# 353/355 Fetching player with id: 1630270
# 354/355 Fetching player with id: 202330
# 355/355 Fetching player with id: 1630539

# %%
grouped_count = df['Player_Name'].value_counts().reset_index()
grouped_count.columns = ['Player_Name', 'Count']

grouped = df.groupby('Player_Name').mean(numeric_only = True)
grouped = grouped.merge(grouped_count, on = 'Player_Name')
grouped = grouped[grouped['Count'] >= 3]
grouped = grouped.round(decimals = 2)
grouped = grouped.sort_values('PTS', ascending = True)
# Out:
# Creating Year: 2010
# Creating Year: 2011
# Creating Year: 2012
# Creating Year: 2013
# Creating Year: 2014
# Creating Year: 2015
# Creating Year: 2016
# Creating Year: 2017
# Creating Year: 2018
# Creating Year: 2019
# Creating Year: 2020
# Creating Year: 2021
# Creating Year: 2022
# Creating Year: 2023

# %%
grouped
# Out:
#           Player_Name  Player_ID   MIN   FGM   FGA  FG_PCT  FG3M  FG3A  \
# 74   Chandler Parsons   202718.0 -0.32 -2.70 -2.80   -0.16 -1.06 -1.12
# 543      Tyrese Maxey  1630178.0  3.23 -1.57 -1.83   -0.02 -1.49 -1.44
# 54      Brian Roberts   203148.0 -8.92 -2.19 -3.63   -0.05 -0.84 -1.70
# 345      Kyrie Irving   202681.0 -0.37 -2.03 -1.03   -0.09 -1.11 -0.24
# 7        Al Jefferson     2744.0  0.19 -2.68 -2.62   -0.11 -0.02  0.10
# ..                ...        ...   ...   ...   ...     ...   ...   ...
# 177    Frank Kaminsky  1626163.0  6.86  2.56  5.11    0.05  0.81  2.59
# 94   D'Angelo Russell  1626156.0  4.32  2.57  3.63    0.04  0.71  2.02
# 480     Sasha Vujacic     2756.0  6.62  2.57  2.78    0.13  1.72  1.66
# 519     Toney Douglas   201962.0  6.12  2.76  3.52    0.16  2.04  2.23
# 258      Jayson Tatum  1628369.0  1.56  1.86  3.27    0.02  1.69  2.92
#
#      FG3_PCT   FTM  ...   REB   AST   STL   BLK   TOV    PF   PTS  PLUS_MINUS  \
# 74     -0.18 -0.93  ... -0.97 -1.46  0.42  0.67 -1.12 -0.29 -7.39        1.66
# 543    -0.27 -2.23  ... -0.29  3.60 -0.18  0.65 -0.41 -1.16 -6.86        2.94
# 54     -0.31 -1.18  ... -0.22 -1.77 -0.51 -0.07 -1.01 -1.42 -6.39       -5.57
# 345    -0.13 -1.18  ...  0.36  0.39  0.45 -0.17 -0.10 -0.33 -6.34       -6.38
# 7      -0.01 -0.73  ... -1.51 -0.42 -0.71 -0.40  0.03  0.61 -6.12      -12.49
# ..       ...   ...  ...   ...   ...   ...   ...   ...   ...   ...         ...
# 177     0.01  0.61  ...  2.07 -0.34 -0.45 -0.12 -0.36  0.24  6.55        6.61
# 94      0.03  0.72  ...  0.16  1.72  0.08 -0.11 -0.21 -0.07  6.57        1.76
# 480     0.13  0.29  ...  0.13 -0.20 -0.22 -0.07  0.64  0.90  7.13        3.35
# 519     0.21  0.00  ... -0.00  1.49  0.10  0.18  0.01  0.26  7.56       -0.32
# 258     0.06  2.50  ...  0.80  0.49  0.05 -0.02 -0.29  0.22  7.92        6.37
#
#      VIDEO_AVAILABLE  Count
# 74             -0.06      3
# 543             0.00      3
# 54              0.01      3
# 345            -0.00      7
# 7               0.01      5
# ..               ...    ...
# 177            -0.03      4
# 94             -0.02      6
# 480             0.00      3
# 519            -0.00      4
# 258            -0.01      6
#
# [246 rows x 24 columns]

# %%
df.to_csv(r"C:\\Users\\tuke-\\OneDrive - Cal Poly\\2_Winter_2024\\GSB521\\combined_data.csv", index=False)
